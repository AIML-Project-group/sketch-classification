# %% [markdown]
# <a href="https://www.kaggle.com/code/mukeshgurpude/sketch-classification-separate-data?scriptVersionId=107103414" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from pathlib import Path
import shutil

# %%
def _copy(self: Path, target):
    assert self.is_file()
    shutil.copy(self, target/(self.name + self.suffix))
Path.copy = _copy

# %%
INPUT_DIR = '../input/cybertron-sketches/png'
INPUT = Path(INPUT_DIR)

OUTPUT = Path('./')

for folder in ('test', 'train'):
    if not (OUTPUT/folder).exists():
        (OUTPUT/folder).mkdir()

# %%
NUM_IMAGES = 80        # Number of images for each class
TRAINING_SPLIT = 75    # Percentage of images to be used for training

NUM_TRAINING_IMAGES = int(NUM_IMAGES*TRAINING_SPLIT/100)

# %%
for obj in INPUT.iterdir():
    if obj.is_file(): continue

    if not (OUTPUT/'train'/obj.name).exists():
        (OUTPUT/'train'/obj.name).mkdir()
        (OUTPUT/'test'/obj.name).mkdir()

    i = 0
    for img in (INPUT/obj.name).iterdir():
        if i < NUM_TRAINING_IMAGES:
            img.copy(OUTPUT/'train'/obj.name)
        else:
            img.copy(OUTPUT/'test'/obj.name)
        i += 1
